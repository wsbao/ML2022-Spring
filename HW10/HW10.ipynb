# %% [markdown]
# # **Homework 10 - Adversarial Attack**
#
# Slides: https://reurl.cc/7DDxnD
#
# Contact: ntu-ml-2022spring-ta@googlegroups.com

# %% [markdown]
# ## Enviroment & Download
#
# We make use of [pytorchcv](https://pypi.org/project/pytorchcv/) to obtain CIFAR-10 pretrained model, so we need to set up the enviroment first. We also need to download the data (200 images) which we want to attack.

# %%
# # set up environment
# !pip install pytorchcv
# !pip install imgaug

# # download
# !wget https://github.com/DanielLin94144/ML-attack-dataset/files/8167812/data.zip

# # unzip
# !unzip ./data.zip
# !rm ./data.zip

# %%
import torch
import torch.nn as nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 8

# %% [markdown]
# ## Global Settings
# #### **[NOTE]**: Don't change the settings here, or your generated image might not meet the constraint.
# * $\epsilon$ is fixed to be 8. But on **Data section**, we will first apply transforms on raw pixel value (0-255 scale) **by ToTensor (to 0-1 scale)** and then **Normalize (subtract mean divide std)**. $\epsilon$ should be set to $\frac{8}{255 * std}$ during attack.
#
# * Explaination (optional)
#     * Denote the first pixel of original image as $p$, and the first pixel of adversarial image as $a$.
#     * The $\epsilon$ constraints tell us $\left| p-a \right| <= 8$.
#     * ToTensor() can be seen as a function where $T(x) = x/255$.
#     * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#     * After applying ToTensor() and Normalize() on $p$ and $a$, the constraint becomes $\left| N(T(p))-N(T(a)) \right| = \left| \frac{\frac{p}{255}-mean}{std}-\frac{\frac{a}{255}-mean}{std} \right| = \frac{1}{255 * std} \left| p-a \right| <= \frac{8}{255 * std}.$
#     * So, we should set $\epsilon$ to be $\frac{8}{255 * std}$ after ToTensor() and Normalize().

# %%
# the mean and std are the calculated statistics from cifar_10 dataset
cifar_10_mean = (0.491, 0.482, 0.447) # mean for the three channels of cifar_10 images
cifar_10_std = (0.202, 0.199, 0.201) # std for the three channels of cifar_10 images

# convert mean and std to 3-dimensional tensors for future operations
mean = torch.tensor(cifar_10_mean).to(device).view(3, 1, 1)
std = torch.tensor(cifar_10_std).to(device).view(3, 1, 1)

epsilon = 8/255/std

# %%
root = './data' # directory for storing benign images
# benign images: images which do not contain adversarial perturbations
# adversarial images: images which include adversarial perturbations

# %% [markdown]
# ## Data
#
# Construct dataset and dataloader from root directory. Note that we store the filename of each image for future usage.

# %%
import os
import glob
import shutil
import numpy as np
from PIL import Image
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar_10_mean, cifar_10_std)
])

class AdvDataset(Dataset):
    def __init__(self, data_dir, transform):
        self.images = []
        self.labels = []
        self.names = []
        '''
        data_dir
        ├── class_dir
        │   ├── class1.png
        │   ├── ...
        │   ├── class20.png
        '''
        for i, class_dir in enumerate(sorted(glob.glob(f'{data_dir}/*'))):
            images = sorted(glob.glob(f'{class_dir}/*'))
            self.images += images
            self.labels += ([i] * len(images))
            self.names += [os.path.relpath(imgs, data_dir) for imgs in images]
        self.transform = transform
    def __getitem__(self, idx):
        image = self.transform(Image.open(self.images[idx]))
        label = self.labels[idx]
        return image, label
    def __getname__(self):
        return self.names
    def __len__(self):
        return len(self.images)

adv_set = AdvDataset(root, transform=transform)
adv_names = adv_set.__getname__()
adv_loader = DataLoader(adv_set, batch_size=batch_size, shuffle=False)

print(f'number of images = {adv_set.__len__()}')
# Out:
# number of images = 200

# %% [markdown]
# ## Utils -- Benign Images Evaluation

# %%
# to evaluate the performance of model on benign images
def epoch_benign(model, loader, loss_fn):
    model.eval()
    train_acc, train_loss = 0.0, 0.0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        yp = model(x)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
    return train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# %% [markdown]
# ## Utils -- Attack Algorithm

# %%
# perform fgsm attack
def fgsm(model, x, y, loss_fn, epsilon=epsilon):
    x_adv = x.detach().clone() # initialize x_adv as original benign image x
    x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
    loss = loss_fn(model(x_adv), y) # calculate loss
    loss.backward() # calculate gradient
    # fgsm: use gradient ascent on x_adv to maximize loss
    grad = x_adv.grad.detach()
    x_adv = x_adv + epsilon * grad.sign()
    return x_adv

# set alpha as the step size in Global Settings section
# alpha and num_iter can be decided by yourself
alpha = 0.8/255/std
def ifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=100):
    x_adv = x
    # write a loop of num_iter to represent the iterative times
    for i in range(num_iter):
        # x_adv = fgsm(model, x_adv, y, loss_fn, alpha) # call fgsm with (epsilon = alpha) to obtain new x_adv
        x_adv = x_adv.detach().clone()
        x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
        loss = loss_fn(model(x_adv), y) # calculate loss
        loss.backward() # calculate gradient
        # fgsm: use gradient ascent on x_adv to maximize loss
        grad = x_adv.grad.detach()
        x_adv = x_adv + alpha * grad.sign()

        x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon) # clip new x_adv back to [x-epsilon, x+epsilon]
    return x_adv

def mifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=100, decay=1.0):
    x_adv = x
    # initialze momentum tensor
    momentum = torch.zeros_like(x).detach().to(device)
    # write a loop of num_iter to represent the iterative times
    for i in range(num_iter):
        x_adv = x_adv.detach().clone()
        x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
        loss = loss_fn(model(x_adv), y) # calculate loss
        loss.backward() # calculate gradient
        # TODO: Momentum calculation
        grad = x_adv.grad.detach()
        momentum = grad = decay * momentum + grad / grad.norm(p=1)
        x_adv = x_adv + alpha * grad.sign()
        x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon) # clip new x_adv back to [x-epsilon, x+epsilon]
    return x_adv

def dimifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=100, decay=1.0, p=0.5, keep_ratio_min=0.9):
    x_adv = x
    # initialze momentum tensor
    momentum = torch.zeros_like(x).detach().to(device)
    # write a loop of num_iter to represent the iterative times
    for i in range(num_iter):
        x_adv = x_adv.detach().clone()
        x_adv_raw = x_adv.clone()
        if torch.rand(1).item() <= p:
            h, w = x_adv.shape[-2:]
            h_min = int(h * keep_ratio_min)
            w_min = int(w * keep_ratio_min) if h != w else h_min
            h_rnd = torch.randint(h_min, h + 1, (1,)).item()
            w_rnd = torch.randint(w_min, w + 1, (1,)).item() if h != w else h_rnd
            x_adv = transforms.Resize((h_rnd, w_rnd))(x_adv)
            left = torch.randint(0, w - w_rnd + 1, (1,)).item()
            top = torch.randint(0, h - h_rnd + 1, (1,)).item()
            right = w - w_rnd - left
            bottom = h - h_rnd - top
            x_adv = transforms.Pad([left, top, right, bottom])(x_adv)
        x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
        loss = loss_fn(model(x_adv), y) # calculate loss
        loss.backward() # calculate gradient
        # TODO: Momentum calculation
        grad = x_adv.grad.detach()
        momentum = grad = decay * momentum + grad / grad.norm(p=1)
        x_adv = x_adv_raw + alpha * grad.sign()
        x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon) # clip new x_adv back to [x-epsilon, x+epsilon]
    return x_adv

# %% [markdown]
# ## Utils -- Attack
# * Recall
#   * ToTensor() can be seen as a function where $T(x) = x/255$.
#   * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#
# * Inverse function
#   * Inverse Normalize() can be seen as a function where $N^{-1}(x) = x*std+mean$ where $mean$ and $std$ are constants.
#   * Inverse ToTensor() can be seen as a function where $T^{-1}(x) = x*255$.
#
# * Special Noted
#   * ToTensor() will also convert the image from shape (height, width, channel) to shape (channel, height, width), so we also need to transpose the shape back to original shape.
#   * Since our dataloader samples a batch of data, what we need here is to transpose **(batch_size, channel, height, width)** back to **(batch_size, height, width, channel)** using np.transpose.

# %%
# perform adversarial attack and generate adversarial examples
def gen_adv_examples(model, loader, attack, loss_fn):
    model.eval()
    adv_names = []
    train_acc, train_loss = 0.0, 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)
        x_adv = attack(model, x, y, loss_fn) # obtain adversarial examples
        yp = model(x_adv)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
        # store adversarial examples
        adv_ex = ((x_adv) * std + mean).clamp(0, 1) # to 0-1 scale
        adv_ex = (adv_ex * 255).clamp(0, 255) # 0-255 scale
        adv_ex = adv_ex.detach().cpu().data.numpy().round() # round to remove decimal part
        adv_ex = adv_ex.transpose((0, 2, 3, 1)) # transpose (bs, C, H, W) back to (bs, H, W, C)
        adv_examples = adv_ex if i == 0 else np.r_[adv_examples, adv_ex]
    return adv_examples, train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# create directory which stores adversarial examples
def create_dir(data_dir, adv_dir, adv_examples, adv_names):
    if os.path.exists(adv_dir) is not True:
        _ = shutil.copytree(data_dir, adv_dir)
    for example, name in zip(adv_examples, adv_names):
        im = Image.fromarray(example.astype(np.uint8)) # image pixel value should be unsigned int
        im.save(os.path.join(adv_dir, name))

# %% [markdown]
# ## Example of Ensemble Attack
# * Ensemble multiple models as your proxy model to increase the black-box transferability ([paper](https://arxiv.org/abs/1611.02770))

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model

class ensembleNet(nn.Module):
    def __init__(self, model_names):
        super().__init__()
        self.models = nn.ModuleList([ptcv_get_model(name, pretrained=True) for name in model_names])
        # self.softmax = nn.Softmax(dim=1)
    def forward(self, x):
        for i, m in enumerate(self.models):
        # TODO: sum up logits from multiple models  
            ensemble_logits = m(x) if i==0 else m(x) + ensemble_logits
        return ensemble_logits / len(self.models)

# %% [markdown]
# * Construct your ensemble model

# %%
model_names = [
    # 'nin_cifar10',
    'resnet20_cifar10',
    # 'preresnet20_cifar10'
    'seresnet20_cifar10',
    'densenet40_k12_cifar10',
]
ensemble_model = ensembleNet(model_names).to(device)
ensemble_model.eval()
# Out:
# ensembleNet(
#   (models): ModuleList(
#     (0): CIFARResNet(
#       (features): Sequential(
#         (init_block): ConvBlock(
#           (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (stage1): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage2): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage3): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=64, out_features=10, bias=True)
#     )
#     (1): CIFARSEResNet(
#       (features): Sequential(
#         (init_block): ConvBlock(
#           (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (stage1): Sequential(
#           (unit1): SEResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (se): SEBlock(
#               (pool): AdaptiveAvgPool2d(output_size=1)
#               (conv1): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#               (activ): ReLU(inplace=True)
#               (conv2): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#               (sigmoid): Sigmoid()
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): SEResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (se): SEBlock(
#               (pool): AdaptiveAvgPool2d(output_size=1)
#               (conv1): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#               (activ): ReLU(inplace=True)
#               (conv2): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#               (sigmoid): Sigmoid()
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): SEResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (se): SEBlock(
#               (pool): AdaptiveAvgPool2d(output_size=1)
#               (conv1): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#               (activ): ReLU(inplace=True)
#               (conv2): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#               (sigmoid): Sigmoid()
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage2): Sequential(
#           (unit1): SEResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (se): SEBlock(
#               (pool): AdaptiveAvgPool2d(output_size=1)
#               (conv1): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#               (activ): ReLU(inplace=True)
#               (conv2): Conv2d(2, 32, kernel_size=(1, 1), stride=(1, 1))
#               (sigmoid): Sigmoid()
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): SEResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (se): SEBlock(
#               (pool): AdaptiveAvgPool2d(output_size=1)
#               (conv1): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#               (activ): ReLU(inplace=True)
#               (conv2): Conv2d(2, 32, kernel_size=(1, 1), stride=(1, 1))
#               (sigmoid): Sigmoid()
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): SEResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (se): SEBlock(
#               (pool): AdaptiveAvgPool2d(output_size=1)
#               (conv1): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#               (activ): ReLU(inplace=True)
#               (conv2): Conv2d(2, 32, kernel_size=(1, 1), stride=(1, 1))
#               (sigmoid): Sigmoid()
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage3): Sequential(
#           (unit1): SEResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (se): SEBlock(
#               (pool): AdaptiveAvgPool2d(output_size=1)
#               (conv1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#               (activ): ReLU(inplace=True)
#               (conv2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#               (sigmoid): Sigmoid()
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): SEResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (se): SEBlock(
#               (pool): AdaptiveAvgPool2d(output_size=1)
#               (conv1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#               (activ): ReLU(inplace=True)
#               (conv2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#               (sigmoid): Sigmoid()
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): SEResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (se): SEBlock(
#               (pool): AdaptiveAvgPool2d(output_size=1)
#               (conv1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#               (activ): ReLU(inplace=True)
#               (conv2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#               (sigmoid): Sigmoid()
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=64, out_features=10, bias=True)
#     )
#     (2): CIFARDenseNet(
#       (features): Sequential(
#         (init_block): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (stage1): Sequential(
#           (unit1): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(24, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit2): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(36, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit3): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit4): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(60, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit5): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(72, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit6): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(84, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit7): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit8): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(108, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit9): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(120, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit10): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(132, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit11): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(144, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit12): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(156, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#         )
#         (stage2): Sequential(
#           (trans2): TransitionBlock(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(168, 84, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#           )
#           (unit1): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(84, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit2): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit3): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(108, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit4): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(120, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit5): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(132, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit6): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(144, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit7): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(156, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit8): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(168, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit9): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(180, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit10): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(192, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit11): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(204, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(204, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit12): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(216, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#         )
#         (stage3): Sequential(
#           (trans3): TransitionBlock(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(228, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(228, 114, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#           )
#           (unit1): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(114, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(114, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit2): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(126, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(126, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit3): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(138, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(138, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit4): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(150, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(150, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit5): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(162, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(162, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit6): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(174, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(174, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit7): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(186, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(186, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit8): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(198, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(198, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit9): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(210, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(210, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit10): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(222, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(222, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit11): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(234, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(234, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit12): DenseSimpleUnit(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(246, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(246, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#         )
#         (post_activ): PreResActivation(
#           (bn): BatchNorm2d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=258, out_features=10, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## Model / Loss Function
#
# Model list is available [here](https://github.com/osmr/imgclsmob/blob/master/pytorch/pytorchcv/model_provider.py). Please select models which has _cifar10 suffix. Some of the models cannot be accessed/loaded. You can safely skip them since TA's model will not use those kinds of models.

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model

# model = ptcv_get_model('resnet110_cifar10', pretrained=True).to(device)
model = ensemble_model
loss_fn = nn.CrossEntropyLoss()

benign_acc, benign_loss = epoch_benign(model, adv_loader, loss_fn)
print(f'benign_acc = {benign_acc:.5f}, benign_loss = {benign_loss:.5f}')
# Out:
# benign_acc = 0.95500, benign_loss = 0.15792

# %% [markdown]
# ## FGSM

# %%
adv_examples, fgsm_acc, fgsm_loss = gen_adv_examples(model, adv_loader, fgsm, loss_fn)
print(f'fgsm_acc = {fgsm_acc:.5f}, fgsm_loss = {fgsm_loss:.5f}')

create_dir(root, 'fgsm', adv_examples, adv_names)
# Out:
# fgsm_acc = 0.40500, fgsm_loss = 2.49615

# %% [markdown]
# ## I-FGSM

# %%
adv_examples, ifgsm_acc, ifgsm_loss = gen_adv_examples(model, adv_loader, ifgsm, loss_fn)
print(f'ifgsm_acc = {ifgsm_acc:.5f}, ifgsm_loss = {ifgsm_loss:.5f}')

create_dir(root, 'ifgsm', adv_examples, adv_names)
# Out:
# ifgsm_acc = 0.00000, ifgsm_loss = 19.23653

# %% [markdown]
# ## MI-FGSM

# %%
adv_examples, mifgsm_acc, mifgsm_loss = gen_adv_examples(model, adv_loader, mifgsm, loss_fn)
print(f'mifgsm_acc = {mifgsm_acc:.5f}, mifgsm_loss = {mifgsm_loss:.5f}')

create_dir(root, 'mifgsm', adv_examples, adv_names)
# Out:
# mifgsm_acc = 0.00000, mifgsm_loss = 20.44315

# %% [markdown]
# ## DI-MI-FGSM
# Reference: [paper](https://arxiv.org/pdf/1803.06978.pdf)

# %%
adv_examples, dimifgsm_acc, dimifgsm_loss = gen_adv_examples(model, adv_loader, dimifgsm, loss_fn)
print(f'dimifgsm_acc = {dimifgsm_acc:.5f}, dimifgsm_loss = {dimifgsm_loss:.5f}')

create_dir(root, 'dimifgsm', adv_examples, adv_names)
# Out:
# dimifgsm_acc = 0.00000, dimifgsm_loss = 17.76917

# %% [markdown]
# ## Compress the images
# * Submit the .tgz file to [JudgeBoi](https://ml.ee.ntu.edu.tw/hw10/)

# %%
# %cd fgsm
# !tar zcvf ../fgsm.tgz *
# %cd ..

# %cd ifgsm
# !tar zcvf ../ifgsm.tgz *
# %cd ..
# Out:
# d:\Wei-shun Bao\Learning\Codes\ML2022-Spring\HW10\fgsm
# d:\Wei-shun Bao\Learning\Codes\ML2022-Spring\HW10
# d:\Wei-shun Bao\Learning\Codes\ML2022-Spring\HW10\ifgsm
# a airplane
# a automobile
# a bird
# a cat
# a deer
# a dog
# a frog
# a horse
# a ship
# a truck
# a truck/truck1.png
# a truck/truck10.png
# a truck/truck11.png
# a truck/truck12.png
# a truck/truck13.png
# a truck/truck14.png
# a truck/truck15.png
# a truck/truck16.png
# a truck/truck17.png
# a truck/truck18.png
# a truck/truck19.png
# a truck/truck2.png
# a truck/truck20.png
# a truck/truck3.png
# a truck/truck4.png
# a truck/truck5.png
# a truck/truck6.png
# a automobile/automobile13.png
# a automobile/automobile14.png
# a automobile/automobile15.png
# a automobile/automobile16.png
# a automobile/automobile17.png
# a automobile/automobile18.png
# a automobile/automobile19.png
# a automobile/automobile2.png
# a automobile/automobile20.png
# a automobile/automobile3.png
# a automobile/automobile4.png
# a automobile/automobile5.png
# a automobile/automobile6.png
# a automobile/automobile7.png
# a automobile/automobile8.png
# a automobile/automobile9.png
# a airplane/airplane1.png
# a airplane/airplane10.png
# a airplane/airplane11.png
# a airplane/airplane12.png
# a airplane/airplane13.png
# a airplane/airplane14.png
# a airplane/airplane15.png
# a airplane/airplane16.png
# a airplane/airplane17.png
# a airplane/airplane18.png
# a airplane/airplane19.png
# a airplane/airplane2.png
# a airplane/airplane20.png
# a airplane/airplane3.png
# a airplane/airplane4.png
# a airplane/airplane5.png
# a airplane/airplane6.png
# a airplane/airplane7.png
# a airplane/airplane8.png
# a airplane/airplane9.png
# d:\Wei-shun Bao\Learning\Codes\ML2022-Spring\HW10
# a airplane
# a automobile
# a bird
# a cat
# a deer
# a dog
# a frog
# a horse
# a ship
# a truck
# a truck/truck1.png
# a truck/truck10.png
# a truck/truck11.png
# a truck/truck12.png
# a truck/truck13.png
# a truck/truck14.png
# a truck/truck15.png
# a truck/truck16.png
# a truck/truck17.png
# a truck/truck18.png
# a truck/truck19.png
# a truck/truck2.png
# a truck/truck20.png
# a truck/truck3.png
# a truck/truck4.png
# a truck/truck5.png
# a truck/truck6.png
# a truck/truck7.png
# a truck/truck8.png
# a truck/truck9.png
# a ship/ship1.png
# a ship/ship10.png
# a ship/ship11.png
# a ship/ship12.png
# a ship/ship13.png
# a ship/ship14.png
# a ship/ship15.png
# a ship/ship16.png
# a ship/ship17.png
# a ship/ship18.png
# a ship/ship19.png
# a ship/ship2.png
# a ship/ship20.png
# a ship/ship3.png
# a ship/ship4.png
# a ship/ship5.png
# a ship/ship6.png
# a ship/ship7.png
# a ship/ship8.png
# a ship/ship9.png
# a horse/horse1.png
# a horse/horse10.png
# a horse/horse11.png
# a horse/horse12.png
# a horse/horse13.png
# a horse/horse14.png
# a horse/horse15.png
# a horse/horse16.png
# a horse/horse17.png
# a horse/horse18.png
# a horse/horse19.png
# a horse/horse2.png
# a horse/horse20.png
# a horse/horse3.png
# a horse/horse4.png
# a horse/horse5.png
# a horse/horse6.png
# a horse/horse7.png
# a horse/horse8.png
# a horse/horse9.png
# a frog/frog1.png
# a frog/frog10.png
# a frog/frog11.png
# a frog/frog12.png
# a frog/frog13.png
# a frog/frog14.png
# a frog/frog15.png
# a frog/frog16.png
# a frog/frog17.png
# a frog/frog18.png
# a frog/frog19.png
# a frog/frog2.png
# a frog/frog20.png
# a frog/frog3.png
# a frog/frog4.png
# a frog/frog5.png
# a frog/frog6.png
# a frog/frog7.png
# a frog/frog8.png
# a frog/frog9.png
# a dog/dog1.png
# a dog/dog10.png
# a dog/dog11.png
# a dog/dog12.png
# a dog/dog13.png
# a dog/dog14.png
# a dog/dog15.png
# a dog/dog16.png
# a dog/dog17.png
# a dog/dog18.png
# a dog/dog19.png
# a dog/dog2.png
# a dog/dog20.png
# a dog/dog3.png
# a dog/dog4.png
# a dog/dog5.png
# a dog/dog6.png
# a dog/dog7.png
# a dog/dog8.png
# a dog/dog9.png
# a deer/deer1.png
# a automobile/automobile7.png
# a automobile/automobile8.png
# a automobile/automobile9.png
# a airplane/airplane1.png
# a airplane/airplane10.png
# a airplane/airplane11.png
# a airplane/airplane12.png
# a airplane/airplane13.png
# a airplane/airplane14.png
# a airplane/airplane15.png
# a airplane/airplane16.png
# a airplane/airplane17.png
# a airplane/airplane18.png
# a airplane/airplane19.png
# a airplane/airplane2.png
# a airplane/airplane20.png
# a airplane/airplane3.png
# a airplane/airplane4.png
# a airplane/airplane5.png
# a airplane/airplane6.png
# a airplane/airplane7.png
# a airplane/airplane8.png
# a airplane/airplane9.png

# %%
# %cd dimifgsm
# !tar zcvf ../dimifgsm.tgz *
# %cd ..
# Out:
# d:\Wei-shun Bao\Learning\Codes\ML2022-Spring\HW10\dimifgsm
# d:\Wei-shun Bao\Learning\Codes\ML2022-Spring\HW10
# a airplane
# a automobile
# a bird
# a cat
# a deer
# a dog
# a frog
# a horse
# a ship
# a truck
# a truck/truck1.png
# a truck/truck10.png
# a truck/truck11.png
# a truck/truck12.png
# a truck/truck13.png
# a truck/truck14.png
# a truck/truck15.png
# a truck/truck16.png
# a truck/truck17.png
# a truck/truck18.png
# a truck/truck19.png
# a truck/truck2.png
# a truck/truck20.png
# a truck/truck3.png
# a truck/truck4.png
# a truck/truck5.png
# a truck/truck6.png
# a truck/truck7.png
# a truck/truck8.png
# a truck/truck9.png
# a ship/ship1.png
# a ship/ship10.png
# a ship/ship11.png
# a ship/ship12.png
# a ship/ship13.png
# a ship/ship14.png
# a ship/ship15.png
# a ship/ship16.png
# a ship/ship17.png
# a ship/ship18.png
# a ship/ship19.png
# a ship/ship2.png
# a ship/ship20.png
# a ship/ship3.png
# a ship/ship4.png
# a ship/ship5.png
# a ship/ship6.png
# a ship/ship7.png
# a ship/ship8.png
# a ship/ship9.png
# a horse/horse1.png
# a horse/horse10.png
# a horse/horse11.png
# a horse/horse12.png
# a horse/horse13.png
# a horse/horse14.png
# a horse/horse15.png
# a horse/horse16.png
# a horse/horse17.png
# a horse/horse18.png
# a horse/horse19.png
# a horse/horse2.png
# a horse/horse20.png
# a horse/horse3.png
# a horse/horse4.png
# a horse/horse5.png
# a horse/horse6.png
# a horse/horse7.png
# a horse/horse8.png
# a horse/horse9.png
# a frog/frog1.png
# a frog/frog10.png
# a frog/frog11.png
# a frog/frog12.png
# a frog/frog13.png
# a frog/frog14.png
# a frog/frog15.png
# a frog/frog16.png
# a frog/frog17.png
# a frog/frog18.png
# a frog/frog19.png
# a frog/frog2.png
# a frog/frog20.png
# a frog/frog3.png
# a frog/frog4.png
# a frog/frog5.png
# a frog/frog6.png
# a frog/frog7.png
# a frog/frog8.png
# a frog/frog9.png
# a dog/dog1.png
# a dog/dog10.png
# a dog/dog11.png
# a dog/dog12.png
# a dog/dog13.png
# a dog/dog14.png
# a dog/dog15.png
# a dog/dog16.png
# a dog/dog17.png
# a dog/dog18.png
# a dog/dog19.png
# a dog/dog2.png
# a dog/dog20.png
# a dog/dog3.png
# a dog/dog4.png
# a dog/dog5.png
# a dog/dog6.png
# a dog/dog7.png
# a dog/dog8.png
# a dog/dog9.png
# a deer/deer1.png
# a deer/deer10.png
# a deer/deer11.png
# a deer/deer12.png
# a deer/deer13.png
# a deer/deer14.png
# a deer/deer15.png
# a deer/deer16.png
# a deer/deer17.png
# a deer/deer18.png
# a deer/deer19.png
# a deer/deer2.png
# a deer/deer20.png
# a deer/deer3.png
# a deer/deer4.png
# a deer/deer5.png
# a deer/deer6.png
# a deer/deer7.png
# a deer/deer8.png
# a deer/deer9.png
# a cat/cat1.png
# a cat/cat10.png
# a cat/cat11.png
# a cat/cat12.png
# a cat/cat13.png
# a cat/cat14.png
# a cat/cat15.png
# a cat/cat16.png
# a cat/cat17.png
# a cat/cat18.png
# a cat/cat19.png
# a cat/cat2.png
# a cat/cat20.png
# a cat/cat3.png
# a cat/cat4.png
# a cat/cat5.png
# a cat/cat6.png
# a cat/cat7.png
# a cat/cat8.png
# a cat/cat9.png
# a bird/bird1.png
# a bird/bird10.png
# a bird/bird11.png
# a bird/bird12.png
# a bird/bird13.png
# a bird/bird14.png
# a bird/bird15.png
# a bird/bird16.png
# a bird/bird17.png
# a bird/bird18.png
# a bird/bird19.png
# a bird/bird2.png
# a bird/bird20.png
# a bird/bird3.png
# a bird/bird4.png
# a bird/bird5.png
# a bird/bird6.png
# a bird/bird7.png
# a bird/bird8.png
# a bird/bird9.png
# a automobile/automobile1.png
# a automobile/automobile10.png
# a automobile/automobile11.png
# a automobile/automobile12.png
# a automobile/automobile13.png
# a automobile/automobile14.png
# a automobile/automobile15.png
# a automobile/automobile16.png
# a automobile/automobile17.png
# a automobile/automobile18.png
# a automobile/automobile19.png
# a automobile/automobile2.png
# a automobile/automobile20.png
# a automobile/automobile3.png
# a automobile/automobile4.png
# a automobile/automobile5.png
# a automobile/automobile6.png
# a automobile/automobile7.png
# a automobile/automobile8.png
# a automobile/automobile9.png
# a airplane/airplane1.png
# a airplane/airplane10.png
# a airplane/airplane11.png
# a airplane/airplane12.png
# a airplane/airplane13.png
# a airplane/airplane14.png
# a airplane/airplane15.png
# a airplane/airplane16.png
# a airplane/airplane17.png
# a airplane/airplane18.png
# a airplane/airplane19.png
# a airplane/airplane2.png
# a airplane/airplane20.png
# a airplane/airplane3.png
# a airplane/airplane4.png
# a airplane/airplane5.png
# a airplane/airplane6.png
# a airplane/airplane7.png
# a airplane/airplane8.png
# a airplane/airplane9.png

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 20))
cnt = 0
for i, cls_name in enumerate(classes):
    path = f'{cls_name}/{cls_name}1.png'
    # benign image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./data/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'benign: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
    # adversarial image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    # im = Image.open(f'./fgsm/{path}')
    # im = Image.open(f'./ifgsm/{path}')
    # im = Image.open(f'./mifgsm/{path}')
    im = Image.open(f'./dimifgsm/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'adversarial: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Report Question
# * Make sure you follow below setup: the source model is "resnet110_cifar10", applying the vanilla fgsm attack on `dog2.png`. You can find the perturbed image in `fgsm/dog2.png`.

# %%
# original image
path = f'dog/dog2.png'
im = Image.open(f'./data/{path}')
logit = model(transform(im).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'benign: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')
plt.imshow(np.array(im))
plt.tight_layout()
plt.show()

# adversarial image 
# im = Image.open(f'./fgsm/{path}')
# im = Image.open(f'./ifgsm/{path}')
# im = Image.open(f'./mifgsm/{path}')
im = Image.open(f'./dimifgsm/{path}')
logit = model(transform(im).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'adversarial: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')
plt.imshow(np.array(im))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Passive Defense - JPEG compression
# JPEG compression by imgaug package, compression rate set to 70
#
# Reference: https://imgaug.readthedocs.io/en/latest/source/api_augmenters_arithmetic.html#imgaug.augmenters.arithmetic.JpegCompression

# %%
import imgaug.augmenters as iaa

# pre-process image
x = transforms.ToTensor()(im)*255
x = x.permute(1, 2, 0).numpy()
compressed_x = x.astype(np.uint8)

# TODO: use "imgaug" package to perform JPEG compression (compression rate = 70)
compressed_x = iaa.arithmetic.compress_jpeg(compressed_x, compression=70)

logit = model(transform(compressed_x).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'JPEG adversarial: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')


plt.imshow(compressed_x)
plt.tight_layout()
plt.show()
